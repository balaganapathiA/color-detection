# %%
import cv2
import pandas as pd



img_path = "/home/balaganapathi/Downloads/archive/colorpic.jpg"
img = cv2.imread(img_path)


index=["color","color_name","hex","R","G","B"]
csv = pd.read_csv('/home/balaganapathi/Downloads/archive/colors.csv', names=index, header=None)

def getColorName(R,G,B):
    minimum = 1000
    for i in range(len(csv)):
        d = abs(R- int(csv.loc[i,"R"])) + abs(G- int(csv.loc[i,"G"]))+ abs(B- int(csv.loc[i,"B"]))
        if(d<minimum):
            minimum = d
            color_name = csv.loc[i,"color_name"]
    return color_name

clicked = False
r = g = b = xpos = ypos = 0


def draw_function(event, x,y,flags,param):
    if event == cv2.EVENT_LBUTTONDBLCLK:
        global b,g,r,xpos,ypos, clicked
        clicked = True
        xpos = x
        ypos = y
        b,g,r = img[y,x]
        b = int(b)
        g = int(g)
        r = int(r)


cv2.namedWindow('color detection')
cv2.setMouseCallback('color detection',draw_function)


while(1):
    
    cv2.imshow("color detection",img)
    if (clicked):
        #cv2.rectangle(image, startpoint, endpoint, color, thickness)-1 fills entire rectangle 
        cv2.rectangle(img,(20,20), (750,60), (b,g,r), -1)
        color_name = getColorName(r,g,b) + ' R='+ str(r) +  ' G='+ str(g) +  ' B='+ str(b)
        #cv2.putText(img,text,start,font(0-7),fontScale,color,thickness,lineType )
        cv2.putText(img, color_name,(50,50),2,0.8,(255,255,255),2,cv2.LINE_AA)
        #For very light colours we will display text in black colour
        if(r+g+b>=600):
            cv2.putText(img, color_name,(50,50),2,0.8,(0,0,0),2,cv2.LINE_AA)
            
        clicked=False
    #hit Q TO END THE PRGRAM 
    if cv2.waitKey(20) & 0xFF ==ord('q'):
        break
    
cv2.destroyAllWindows()

import numpy as np
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
color = np.uint8([[[b,g,r]]])
hsv_color = cv2.cvtColor(color,cv2.COLOR_BGR2HSV)
lower_range = np.array([hsv_color[0][0][0] - 10,100,100])
upper_range = np.array([hsv_color[0][0][0] + 10,255,255])

mask = cv2.inRange(hsv, lower_range, upper_range)

cv2.imshow('mask', mask)
cv2.waitKey(0)
cv2.destroyAllWindows()
